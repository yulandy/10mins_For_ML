# %% [markdown]
# By [Yulandy Chiu](https://www.youtube.com/@YulandySpace)
#
# Aided with Gemini/Claude/ChatGPT and modified by Yulandy Chiu
#
# Version: 2024/03/11
#
# Videos:
# * [[10分鐘搞懂機器學習] 2.4 資料對數值預測的影響](https://youtu.be/CNaPHEs4tXY?si=HfBZKn1n_r-HabFG)
#
# Facebook: [Yulandy Chiu的AI資訊站](https://www.facebook.com/yulandychiu)
#
#  This code is licensed under the Creative Commons Attribution-NonCommercial 4.0
#  International License (CC BY-NC 4.0). You are free to use, modify, and share this code for non-commercial purposes, provided you give appropriate credit. For more details, see the LICENSE file or visit: https://creativecommons.org/licenses/by-nc/4.0/
#  © [2024] [Yulandy Chiu](https://www.youtube.com/@YulandySpace)

# %%
# 原始繪圖
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 產生隨機數據
np.random.seed(0)
n_samples = 100
product_price = 50 * np.random.rand(n_samples, 1)  # 產品價格
brand_promotion = 20 * np.random.rand(n_samples, 1)  # 品牌推廣花費
sales = 30 + 0.5 * product_price + 0.8 * brand_promotion + np.random.randn(n_samples, 1) * 5  # 產品銷量，帶有隨機噪聲

# 合併特徵
X = np.concatenate((product_price, brand_promotion), axis=1)

# 擬合線性回歸模型
model = LinearRegression()
model.fit(X, sales)

# 提取模型參數
coefficients = model.coef_
intercept = model.intercept_
print("Coefficients:", coefficients)
print("Intercept:", intercept)

# 繪製數據和模型預測
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(product_price, brand_promotion, sales, color='blue', label='Data points')
ax.set_xlabel('Product Price')
ax.set_ylabel('Brand Promotion Spend')
ax.set_zlabel('Sales')

# 生成預測網格
price_range = np.linspace(min(product_price), max(product_price), 10)
promotion_range = np.linspace(min(brand_promotion), max(brand_promotion), 10)
X_grid, Y_grid = np.meshgrid(price_range, promotion_range)
Z_pred = model.predict(np.array([X_grid.flatten(), Y_grid.flatten()]).T)
Z_grid = Z_pred.reshape(X_grid.shape)

# 繪製模型預測平面
ax.plot_surface(X_grid, Y_grid, Z_grid, alpha=0.5, color='red', label='Regression Plane')

# 添加圖例
plt.show()
# Out:
# Coefficients: [[0.44483545 0.73528831]]
# Intercept: [31.53652653]

# %%
# 1.資料數量不足
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 產生隨機數據
np.random.seed(0)    # 固定隨機種子

n_samples = 10
product_price =  50*np.random.rand(n_samples,1)  # 產品價格
a=product_price
brand_promotion = 20 * np.random.rand(n_samples, 1)  # 品牌推廣花費
sales = 30 + 0.5 * product_price + 0.8 * brand_promotion + np.random.randn(n_samples, 1) * 5  # 產品銷量，帶有隨機噪聲




# 合併特徵
X = np.concatenate((product_price, brand_promotion), axis=1)

# 擬合線性回歸模型
model = LinearRegression()
model.fit(X, sales)

# 提取模型參數
coefficients = model.coef_
intercept = model.intercept_
print("Coefficients:", coefficients)
print("Intercept:", intercept)

# 繪製數據和模型預測
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(product_price, brand_promotion, sales, color='blue', label='Data points')
ax.set_xlabel('Product Price')
ax.set_ylabel('Brand Promotion Spend')
ax.set_zlabel('Sales')

# 生成預測網格
price_range = np.linspace(min(product_price), max(product_price), 10)
promotion_range = np.linspace(min(brand_promotion), max(brand_promotion), 10)
X_grid, Y_grid = np.meshgrid(price_range, promotion_range)
Z_pred = model.predict(np.array([X_grid.flatten(), Y_grid.flatten()]).T)
Z_grid = Z_pred.reshape(X_grid.shape)

# 繪製模型預測平面
ax.plot_surface(X_grid, Y_grid, Z_grid, alpha=0.5, color='red', label='Regression Plane')

# 添加圖例

plt.show()
# Out:
# Coefficients: [[0.88078648 0.703729  ]]
# Intercept: [19.22318297]

# %%
# 2.缺乏代表性資料
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 產生隨機數據
np.random.seed(0)
n_samples = 100  # 偶數
product_price1 = 1+10*np.random.rand(int(n_samples/2),1)   # 產品價格 1-11
product_price2 =  10*np.random.rand(int(n_samples/2),1)+40  # 產品價格 40-50
product_price=np.concatenate((product_price1,product_price2))

brand_promotion1 = 5 * np.random.rand(int(n_samples/2), 1)  # 品牌推廣花費 0-5
brand_promotion2 = 15+ 5 * np.random.rand(int(n_samples/2), 1)  # 品牌推廣花費 15-20
brand_promotion = np.concatenate((brand_promotion1,brand_promotion2))


sales = 30 + 0.5 * product_price + 0.8 * brand_promotion + np.random.randn(n_samples, 1) * 5  # 產品銷量，帶有隨機噪聲

# 合併特徵
X = np.concatenate((product_price, brand_promotion), axis=1)

# 擬合線性回歸模型
model = LinearRegression()
model.fit(X, sales)

# 提取模型參數
coefficients = model.coef_
intercept = model.intercept_
print("Coefficients:", coefficients)
print("Intercept:", intercept)

# 繪製數據和模型預測
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(product_price, brand_promotion, sales, color='blue', label='Data points')
ax.set_xlabel('Product Price')
ax.set_ylabel('Brand Promotion Spend')
ax.set_zlabel('Sales')

# 生成預測網格
price_range = np.linspace(min(product_price), max(product_price), 10)
promotion_range = np.linspace(min(brand_promotion), max(brand_promotion), 10)
X_grid, Y_grid = np.meshgrid(price_range, promotion_range)
Z_pred = model.predict(np.array([X_grid.flatten(), Y_grid.flatten()]).T)
Z_grid = Z_pred.reshape(X_grid.shape)

# 繪製模型預測平面
ax.plot_surface(X_grid, Y_grid, Z_grid, alpha=0.5, color='red', label='Regression Plane')

# 添加圖例


plt.show()
# Out:
# Coefficients: [[0.44568062 0.91846021]]
# Intercept: [29.7181232]

# %%
# 3.資料品質差
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 產生隨機數據
np.random.seed(0)
n_samples = 100
product_price = 50 * np.random.rand(n_samples, 1)  # 產品價格
brand_promotion = 20 * np.random.rand(n_samples, 1)  # 品牌推廣花費




sales1 = 30 + 0.5 * product_price[0:int(n_samples/2)] + 0.8 * brand_promotion[0:int(n_samples/2)] + np.random.randn(int(n_samples/2), 1)* 5  # 產品銷量，帶有隨機噪聲
sales2 = 30 + 0.1 * product_price[int(n_samples/2):] + 0.6 * brand_promotion[int(n_samples/2):] + np.random.randn(int(n_samples/2), 1)* 5  # 產品銷量，資料登記錯誤
sales = np.concatenate((sales1,sales2)) # 合併產品銷量資料

#sales = 30 + 0.5 * product_price + 0.8 * brand_promotion + np.random.randn(n_samples, 1) * 5
# 合併特徵
X = np.concatenate((product_price, brand_promotion), axis=1)

# 擬合線性回歸模型
model = LinearRegression()
model.fit(X, sales)

# 提取模型參數
coefficients = model.coef_
intercept = model.intercept_
print("Coefficients:", coefficients)
print("Intercept:", intercept)

# 繪製數據和模型預測
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(product_price, brand_promotion, sales, color='blue', label='Data points')
ax.set_xlabel('Product Price')
ax.set_ylabel('Brand Promotion Spend')
ax.set_zlabel('Sales')

# 生成預測網格
price_range = np.linspace(min(product_price), max(product_price), 10)
promotion_range = np.linspace(min(brand_promotion), max(brand_promotion), 10)
X_grid, Y_grid = np.meshgrid(price_range, promotion_range)
Z_pred = model.predict(np.array([X_grid.flatten(), Y_grid.flatten()]).T)
Z_grid = Z_pred.reshape(X_grid.shape)

# 繪製模型預測平面
ax.plot_surface(X_grid, Y_grid, Z_grid, alpha=0.5, color='red', label='Regression Plane')

# 添加圖例


plt.show()
# Out:
# Coefficients: [[0.32972752 0.8503636 ]]
# Intercept: [28.0242169]

# %%
# 使用不相關特徵
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 產生隨機數據
np.random.seed(0)
n_samples = 100
product_price = 50 * np.random.rand(n_samples, 1)  # 產品價格 (實際影響銷量的特徵之一，未被使用)
brand_promotion = 20 * np.random.rand(n_samples, 1)  # x2 品牌推廣花費
sales = 30 + 0.5 * product_price + 0.8 * brand_promotion + np.random.randn(n_samples, 1) * 5  # 產品銷量，帶有隨機噪聲



product_manufacturing_cost = 20* np.random.rand(n_samples, 1)  # x1 產品製造成本

# 合併特徵
X = np.concatenate((product_manufacturing_cost, brand_promotion), axis=1)

# 擬合線性回歸模型
model = LinearRegression()
model.fit(X, sales)

# 提取模型參數
coefficients = model.coef_
intercept = model.intercept_
print("Coefficients:", coefficients)
print("Intercept:", intercept)

# 繪製數據和模型預測
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(product_price, brand_promotion, sales, color='blue', label='Data points')
ax.set_xlabel('Manufacturing Cost')
ax.set_ylabel('Brand Promotion Spend')
ax.set_zlabel('Sales')

# 生成預測網格
price_range = np.linspace(min(product_price), max(product_price), 10)
promotion_range = np.linspace(min(brand_promotion), max(brand_promotion), 10)
X_grid, Y_grid = np.meshgrid(price_range, promotion_range)
Z_pred = model.predict(np.array([X_grid.flatten(), Y_grid.flatten()]).T)
Z_grid = Z_pred.reshape(X_grid.shape)

# 繪製模型預測平面
ax.plot_surface(X_grid, Y_grid, Z_grid, alpha=0.5, color='red', label='Regression Plane')

# 添加圖例
plt.show()
# Out:
# Coefficients: [[-0.06459783  0.65846525]]
# Intercept: [43.48150394]
